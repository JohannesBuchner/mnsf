# %%
# %pylab inline
from mnSpecFit import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fv = SpecFitView("expl_fit/band.json")
# Out:
#   analysing data from expl_fit/band_.txt
#
# ------------------------------ ANALYIS ------------------------------
#
#
# Model:
# 	Band
# T:0.00 - 5.00
#
# Best Fit Parameters (1-sigma err):
# 	logNorm:	-1.34	+0.01 -0.03
# 	E$_{\rm p}$:	461.08	+62.71 -15.63
# 	$\alpha$:	-0.66	+0.02 -0.05
# 	$\beta$:	-2.09	+0.04 -0.14
#
# pgstat per d.o.f.:
# 	 507.28/487
#
# Effective number of free parameters:
# 	3.57
#
# LogLikelihood of Best Fit:
# 	-253.64
#
# ---------------------------------------------------------------------

# %%
fv.PlotvFv()

# %%
fv.PlotCounts()

# %%
fv.ViewMarginals()
